# %% [markdown]
# # STRUCTURAL ANALYSIS

# %% [markdown]
# In this notebook can be found the code used to carry out part of the structural analysis including the plots found in the paper.

# %% [markdown]
# ### IMPORTING LIBRARIES

# %%
import pandas as pd
import structural_analysis
import statistics
import structure_validation
import importlib
from scipy import stats
import math

# %%
df_allsp = pd.read_csv("/cluster/gjb_lab/2394007/varalign_runs/varalign_bio_units4/.varalign/prointvar_analysis_data/anks_final_aln.sto_prointvar_structure_table_with_validation.csv") # READS STRUCTURAL DATA TABLE

# %%
df_allsp_csv = pd.read_csv("/cluster/gjb_lab/2394007/varalign_runs/varalign_bio_units4/.varalign/prointvar_analysis_data/anks_final_aln.sto_prointvar_structure_table_with_validation.csv")
# Out:
# 2021-05-14 16:59:33,769 - WARNING - /cluster/gjb_lab/2394007/miniconda/envs/myenv/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (1,14,15,18,19,25,26,28,29,31,33,41,42,43,44,45,46,47,48,51,52,63,64,65,67,69,71,75,76,77,91,95,113,115,118,119,122,123,128,129,132,133,142,143,149,151,153,155,157,161,163,169,206,208,213,214,230,231,232,233,234,243,274,278,280,281,284,300,301,304,308,310) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_allsp_csv.equals(df_allsp)
# Out:
# False

# %%
print(sum(df_allsp == df_allsp_csv))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-e57f8619e30a> in <module>
# ----> 1 print(sum(df_allsp == df_allsp_csv))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
sum(df_allsp != df_allsp_csv)

# %%
structural_analysis.get_struc_info(df_allsp) # UNFILTERED STRUCTURAL DATASET STATS
# Out:
# The dataframe contains information of:
# 35857 residues, 13059 of which are unique
# 209 PDB structures
# 80 different proteins
# 419 unique repeats

# %%
df_allsp_rsrz_filt = structure_validation.filter_rsrz_rscc(df_allsp) # FILTERS STRUCTURAL TABLE SO WE KEEP HIGH QUALITY RESIDUES MEETING OUR RSCC AND RSRZ THRESHOLDS
print(len(df_allsp_rsrz_filt))
# Out:
# 140694

# %%
df_allsp.head()
# Out:
#   AA_A AA_B ACC_A ACC_B ACC_UNB_A ACC_UNB_B ALPHA_A ALPHA_B ATOM_A ATOM_B  \
# 0    Q    A  23.0   1.0      23.0       1.0  -165.9    59.6      C      N
# 1    A    L   1.0   1.0       1.0       1.0    59.6    46.9      C    CD1
# 2    L    L   1.0   1.0       1.0       1.0    52.9    46.9     CA    CD1
# 3    A    L   0.0   1.0       0.0       1.0    45.2    46.9     CB    CD1
# 4    Y    L   2.0   1.0       2.0       1.0    57.1    46.9      O      N
#
#    ... validation_resnum_B validation_resnum_full_B validation_rota_B  \
# 0  ...                 227                      227               nan
# 1  ...                 243                      243                mt
# 2  ...                 243                      243                mt
# 3  ...                 243                      243                mt
# 4  ...                 243                      243                mt
#
#   validation_rscc_B validation_rsr_B validation_rsrz_B validation_said_B  \
# ...

# %%
df_allsp_rsrz_filt.SS_A = df_allsp_rsrz_filt.SS_A.fillna("") # FILL NA WITH "" SO WE CAN PROCESS THE SECONDARY STRUCTURE DATA. NA ARE FOUND ON THOSE RESIDUES PRESENTING NO SS, i.e., COIL
# Out:
# 2021-05-14 16:40:17,690 - WARNING - /cluster/gjb_lab/2394007/miniconda/envs/myenv/lib/python3.7/site-packages/pandas/core/generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
structural_analysis.get_struc_info(df_allsp_rsrz_filt) # FILTERED STRUCTURAL DATASET STATS
# Out:
# The dataframe contains information of:
# 28522 residues, 11186 of which are unique
# 176 PDB structures
# 73 different proteins
# 383 unique repeats

# %%
cons_cols_allsp = structural_analysis.get_cons_cols('/cluster/gjb_lab/2394007/varalign_runs/varalign_bio_units4/anks_final_aln.sto', 'stockholm') # GETS CONSENSUS COLUMNS FROM MSA (OCCUPANCY > 0.5)

# %%
importlib.reload(structural_analysis)
# Out:
# <module 'structural_analysis' from '/cluster/home/2394007/ANK_repeat_analysis/structural_analysis.py'>

# %% [markdown]
# # CONSENSUS RESIDUE SURFACE ACCESSIBILITY CLASS

# %%
rsa_class_dict, rsa_dict = structural_analysis.get_rsa_class_consensus(df_allsp_rsrz_filt, cons_cols_allsp) # RETRIEVES RSA DATA FROM TABLE
# Out:
# The dataframe contains information of:
# 28082 residues, 10992 of which are unique
# 168 PDB structures
# 70 different proteins
# 380 unique repeats
# Processing consensus column 1
# Processing consensus column 2
# Processing consensus column 3
# Processing consensus column 4
# Processing consensus column 5
# Processing consensus column 6
# Processing consensus column 7
# Processing consensus column 8
# Processing consensus column 9
# Processing consensus column 10
# Processing consensus column 11
# Processing consensus column 12
# Processing consensus column 13
# Processing consensus column 14
# Processing consensus column 15
# Processing consensus column 16
# Processing consensus column 17
# Processing consensus column 18
# Processing consensus column 19
# Processing consensus column 20
# Processing consensus column 21
# Processing consensus column 22
# Processing consensus column 23
# Processing consensus column 24
# Processing consensus column 25
# Processing consensus column 26
# ...

# %%
rsa_class_df = structural_analysis.get_rsa_class_df(rsa_class_dict) # CALCULATES PROPORTION OF RSA CLASS PER POSITION

# %%
structural_analysis.plot_rsa_consensus(rsa_class_df, palette = ["royalblue", "tomato", "firebrick"], bwidth = 1.2)

# %% [markdown]
# # MEDIAN RESIDUE SOLVENT ACCESSIBILITY PER POSITION

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
rsa_median = plot_rsa_median(rsa_dict)

# %%
for v in rsa_dict.values():
    print(len(v), statistics.median(v))
# Out:
# 326 32.82299999999999
# 349 38.095
# 357 0.515
# 367 7.042
# 372 1.415
# 367 2.439
# 371 1.596
# 373 2.439
# 372 0.0
# 368 0.32399999999999995
# 361 19.192
# 358 47.382000000000005
# 359 42.857
# 358 32.635000000000005
# 353 27.465
# 351 42.857
# 360 2.465
# 373 63.415
# 363 35.567
# 357 69.192
# 366 1.22
# 355 8.537
# 332 56.3605
# 331 32.222
# 312 50.0
# 320 8.39175
# 313 37.692
# 303 14.899000000000001
# 293 23.926
# 288 13.311499999999999
# 233 nan
# 157 0.0
# 174 48.787000000000006

# %%
def plot_rsa_median(rsa_dict, out = None):
    n = len(rsa_dict.keys())
    ks = list(range(1, n + 1))
    vs = [statistics.median(v) for v in rsa_dict.values()]
    
    palette = {}
    c = 1
    for v in vs:
        if v <= 5:
            palette[c] = "royalblue"
        elif v > 25:
            palette[c] = "firebrick"
        else:
            palette[c] = "tomato"
        c +=1
        
    legend_dict = { 'Core' : 'royalblue', 'Part' : 'tomato', 'Surf' : 'firebrick' }
    patchList = []
    for key in legend_dict:
        data_key = mpatches.Patch(facecolor=legend_dict[key], label=key, edgecolor = "black", linewidth = 3)
        patchList.append(data_key)
        
    i = 1
    lowerbound = []
    upperbound = []
    for v in rsa_dict.values():
        med = statistics.median(v)
        data = pd.Series(v)
        low, up = medianCI(data, 0.95, 0.5)
        lowerbound.append(med-low)
        upperbound.append(up-med)
        i = i+1
    plt.figure(figsize=(180,80))
    plt.rcParams.update({"axes.linewidth": 10})
    ax=sns.barplot(ks, vs, edgecolor = 'black', palette = palette,linewidth = 7.5)#,
                   #ci=[lowerbound, upperbound], errcolor = "black", errwidth = 7.5, capsize = 35)
    plt.errorbar([k-1 for k in ks], vs, yerr=[lowerbound, upperbound], c = "black", linewidth = 10, linestyle="None", capsize = 35.0, capthick = 7.5)
    #ax.set_title('Median RSA per consensus position', pad =100, fontsize = 140)
    ax.tick_params(axis= 'both' , which = 'major', pad = 60, width = 15, length = 50, labelsize = 140)
    ax.set_xlabel("Domain position", labelpad = 100, fontsize = 160)
    ax.set_ylabel('Median RSA', labelpad = 100, fontsize = 160)
    ax.axhline(25, linewidth = 7.5, color = 'black', linestyle = '--')
    ax.axhline(5, linewidth = 7.5, color = 'black', linestyle = '--')
    plt.xlim(-0.7,32.7)
    plt.yticks(np.arange(0, 75, 5))
    legend = plt.legend(handles=patchList, loc='center left', bbox_to_anchor=(1, 0.5),fontsize = 120)
    legend.get_frame().set_linewidth(10)
    legend.get_frame().set_edgecolor("black")
    for legobj in legend.legendHandles:
        legobj.set_linewidth(7.5)
    if out != None:
        plt.savefig(out)
    plt.show()
    return vs

def medianCI(data, ci, p):
    '''
    data: pandas datafame/series or numpy array
    ci: confidence level
    p: percentile' percent, for median it is 0.5
    output: a list with two elements, [lowerBound, upperBound]
    '''
    if type(data) is pd.Series or type(data) is pd.DataFrame:
        #transfer data into np.array
        data = data.values

    #flat to one dimension array
    data = data.reshape(-1)
    data = np.sort(data)
    N = data.shape[0]
    
    lowCount, upCount = stats.binom.interval(ci, N, p, loc=0)
    #given this: https://onlinecourses.science.psu.edu/stat414/node/316
    #lowCount and upCount both refers to  W's value, W follows binomial Dis.
    #lowCount need to change to lowCount-1, upCount no need to change in python indexing
    lowCount -= 1
    # print lowCount, upCount
    return data[int(lowCount)], data[int(upCount)]

# %% [markdown]
# ## CONSENSUS SECONDARY STRUCTURE CLASS ASSIGNMENT

# %%
ss_class_dict = structural_analysis.get_ss_class_consensus(df_allsp_rsrz_filt, cons_cols_allsp) # EXTRACTS SS DATA FROM TABLE AND RETURNS DICTIONARY WITH OCCURRENCE OF SS CLASS PER POSTITION
# Out:
# The dataframe contains information of:
# 28130 residues, 11011 of which are unique
# 176 PDB structures
# 73 different proteins
# 383 unique repeats
# Processing consensus column 1
# Processing consensus column 2
# Processing consensus column 3
# Processing consensus column 4
# Processing consensus column 5
# Processing consensus column 6
# Processing consensus column 7
# Processing consensus column 8
# Processing consensus column 9
# Processing consensus column 10
# Processing consensus column 11
# Processing consensus column 12
# Processing consensus column 13
# Processing consensus column 14
# Processing consensus column 15
# Processing consensus column 16
# Processing consensus column 17
# Processing consensus column 18
# Processing consensus column 19
# Processing consensus column 20
# Processing consensus column 21
# Processing consensus column 22
# Processing consensus column 23
# Processing consensus column 24
# Processing consensus column 25
# Processing consensus column 26
# ...

# %%
ss_class_df = structural_analysis.get_ss_class_df(ss_class_dict) # CALCULATES PROPORTION OF EACH SECONDARY STRUCTURE CLASS PER POISITION

# %%
structural_analysis.plot_ss_class_consensus(ss_class_df, palette = ["mediumseagreen", "firebrick", "cornflowerblue"])

# %% [markdown]
# # CONSENSUS SECONDARY STRUCTURE ASSIGNMENT

# %%
ss_dict = structural_analysis.get_ss_consensus(df_allsp_rsrz_filt, cons_cols_allsp) # EXTRACTS SECONDARY STRUCTURE DATA FROM TABLE AND RETURNS DICTIONARY WITH OCCURRENCE OF SS ELEMENTS PER POSTITION
# Out:
# The dataframe contains information of:
# 28130 residues, 11011 of which are unique
# 176 PDB structures
# 73 different proteins
# 383 unique repeats
# Processing consensus column 1
# Processing consensus column 2
# Processing consensus column 3
# Processing consensus column 4
# Processing consensus column 5
# Processing consensus column 6
# Processing consensus column 7
# Processing consensus column 8
# Processing consensus column 9
# Processing consensus column 10
# Processing consensus column 11
# Processing consensus column 12
# Processing consensus column 13
# Processing consensus column 14
# Processing consensus column 15
# Processing consensus column 16
# Processing consensus column 17
# Processing consensus column 18
# Processing consensus column 19
# Processing consensus column 20
# Processing consensus column 21
# Processing consensus column 22
# Processing consensus column 23
# Processing consensus column 24
# Processing consensus column 25
# Processing consensus column 26
# ...

# %%
ss_df = structural_analysis.get_ss_df(ss_dict) # CALCULATES PROPORTION OF EACH SECONDARY STRUCTURE ELEMENT PER POISITION

# %%
structural_analysis.plot_ss_consensus(ss_df)

# %% [markdown]
# ## ENRICHMENT IN PROTEIN-PROTEIN INTERACTIONS

# %%
df_allsp_rsrz_filt = df_allsp_rsrz_filt[~df_allsp_rsrz_filt.PDB_dbAccessionId_A.isin(["6ha6", "6hl6", "6hl5", "6hc8", "6h9j", "3p3n", "2y0i", "3p3p"])] # REMOVE CERTAIN PDBs FROM DATASET, SINCE ARD NOT IN ORIGINAL CONFORMATION
aln_len_allsp = structural_analysis.get_aln_len('/cluster/gjb_lab/2394007/varalign_runs/varalign_bio_units4/anks_final_aln.sto', 'stockholm') # ALIGNMENT LENGTH (NUMBER OF COLUMNS)
cons_norm_allsp = structural_analysis.get_ppis(df_allsp_rsrz_filt, aln_len_allsp, cons_cols_allsp) # PPI CONTACTS PER POSITION
res_occ_allsp = structural_analysis.get_struc_res_occ(df_allsp_rsrz_filt, cons_cols_allsp, "Protein-Protein") # STRUCTURAL COVERAGE OF EACH POSITION IN OUR DATASET
contacts_allsp = pd.concat([res_occ_allsp, cons_norm_allsp], axis = 1)
contacts_allsp = structural_analysis.get_OR(contacts_allsp) # CALCULATES ENRICHMENT IN PPIs AS WELL AS P-VALUE AND 95% CI
# Out:
# The dataframe contains information of:
# 1753 residues, 931 of which are unique
# 84 PDB structures
# 39 different proteins
# 162 unique repeats
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-3cb7b599b56b> in <module>
#       2 aln_len_allsp = structural_analysis.get_aln_len('/cluster/gjb_lab/2394007/varalign_runs/varalign_bio_units4/anks_final_aln.sto', 'stockholm') # ALIGNMENT LENGTH (NUMBER OF COLUMNS)
#       3 cons_norm_allsp = structural_analysis.get_ppis(df_allsp_rsrz_filt, aln_len_allsp, cons_cols_allsp) # PPI CONTACTS PER POSITION
# ----> 4 res_occ_allsp = structural_analysis.get_struc_res_occ(df_allsp_rsrz_filt, cons_cols_allsp, "Protein-Protein") # STRUCTURAL COVERAGE OF EACH POSITION IN OUR DATASET
#       5 contacts_allsp = pd.concat([res_occ_allsp, cons_norm_allsp], axis = 1)
# ...

# %%
contacts_allsp = structural_analysis.add_surf_class(contacts_allsp) # ADDS COLUMN INDICATIND SURFACE CLASSIFICATION OF EACH POSITION

# %%
contacts_allsp.head()

# %%
structural_analysis.plot_ppi_enrichment(contacts_allsp, "Surface", "surf", "color_surf")

# %% [markdown]
# ## SURFACE ENRICHMENT IN PPIS

# %%
total_ppis = contacts_allsp.contacts.sum()
concave_ppis = contacts_allsp[contacts_allsp.surf == "Concave"].contacts.sum()
convex_ppis = contacts_allsp[contacts_allsp.surf == "Convex"].contacts.sum()
basal_ppis = contacts_allsp[contacts_allsp.surf == "Basal"].contacts.sum()
core_ppis = contacts_allsp[contacts_allsp.surf == "Core"].contacts.sum()
surf_ppis = total_ppis - core_ppis

total_occ = contacts_allsp.occ.sum()
concave_occ = contacts_allsp[contacts_allsp.surf == "Concave"].occ.sum()
convex_occ = contacts_allsp[contacts_allsp.surf == "Convex"].occ.sum()
basal_occ = contacts_allsp[contacts_allsp.surf == "Basal"].occ.sum()
core_occ = contacts_allsp[contacts_allsp.surf == "Core"].occ.sum()
surf_occ = total_occ - core_occ

# %% [markdown]
# ### BURIED RESIDUES VS SURFACE RESIDUES

# %%
oddsratio, pvalue = stats.fisher_exact([[core_ppis, surf_ppis], [core_occ, surf_occ]]) # BURIED RESIDUES DEPLETED IN PPIS RELATIVE TO SURFACE RESIDUES
print(math.log(oddsratio), pvalue)
# Out:
# -1.0277274652077408 1.3775255494626244e-26

# %% [markdown]
# ### CONCAVE RESIDUES VS REST OF SURFACE RESIDUES

# %%
oddsratio, pvalue = stats.fisher_exact([[concave_ppis, surf_ppis-concave_ppis], [concave_occ, surf_occ-concave_occ]]) # CONCAVE SURFACE ENRICHED IN PPIS RELATIVE TO REST OF THE SURFACE
print(math.log(oddsratio), pvalue)
# Out:
# 1.8674383373017602 2.0926464045804222e-111

# %% [markdown]
# ### CONVEX RESIDUES VS REST OF SURFACE RESIDUES

# %%
oddsratio, pvalue = stats.fisher_exact([[convex_ppis, surf_ppis-convex_ppis], [convex_occ, surf_occ-convex_occ]]) # CONVEC SURFACE DEPLETED IN PPIS RELATIVE TO REST OF THE SURFACE
print(math.log(oddsratio), pvalue)
# Out:
# -0.7932342135697418 3.766754855017938e-19

# %% [markdown]
# ### BASAL RESIDUES VS REST OF SURFACE RESIDUES

# %%
oddsratio, pvalue = stats.fisher_exact([[basal_ppis, surf_ppis-basal_ppis], [basal_occ, surf_occ-basal_occ]]) # BASAL SURFACE DEPLETED IN PPIS RELATIVE TO REST OF THE SURFACE
print(math.log(oddsratio), pvalue)
# Out:
# -2.1918131534212972 7.523148389897284e-65

# %% [markdown]
# ### CONVEX RESIDUES VS BASAL RESIDUES

# %%
oddsratio, pvalue = stats.fisher_exact([[convex_ppis, basal_ppis], [convex_occ, basal_occ]]) # CONVEX SURFACE ENRICHED IN PPIS RELATIVE TO BASAL SURFACE
print(math.log(oddsratio), pvalue)
# Out:
# 1.3148863032561462 5.4042564548903466e-15

# %% [markdown]
# ### UMD RESIDUES VS REST OF SURFACE RESIDUES

# %%
umd_cols = [38, 40, 45, 143]

# %%
umd_ppis = contacts_allsp[contacts_allsp.aln_col.isin(umd_cols)].contacts.sum()
umd_occ = contacts_allsp[contacts_allsp.aln_col.isin(umd_cols)].occ.sum()
rest_ppis = contacts_allsp[contacts_allsp.surf != "Core"].contacts.sum() - umd_ppis
rest_occ = contacts_allsp[contacts_allsp.surf != "Core"].occ.sum() - umd_occ

# %%
oddsr, pval = stats.fisher_exact([[umd_ppis, rest_ppis], [umd_occ, rest_occ]]) # UMDs ENRICHED IN PPIS RELATIVE TO OTHER SURFACE RESIDUES
oddsr, pval
# Out:
# (3.6009654965945663, 6.676849150994106e-48)
